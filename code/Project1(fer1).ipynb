'--', label='UN DESA')
    plot(timeseries, color='gray', label='model')
    
    decorate(xlabel='Year', 
             ylabel='World population (billion)',
             title=title)
birth_rate = tables.birthrate10000/10000
empty = TimeSeries()
plot_results(birth_rate, empty, 'life expectancy')
    
decorate(xlabel='Year', 
             ylabel='birth_rate',
             title='birth_rate')

# %%
def plot_results( life_expectancy, timeseries, title):
    """Plot the estimates and the model.
    
    census: TimeSeries of population estimates
    un: TimeSeries of population estimates
    timeseries: TimeSeries of simulation results
    title: string
    """
    plot(life_expectancy, '--', label='UN DESA')
    plot(timeseries, color='gray', label='model')
    
    decorate(xlabel='Year', 
             ylabel='World population (billion)',
             title=title)
life_expectancy= tables._expectancyx1000/1000
empty = TimeSeries()
plot_results(life_expectancy, empty, 'life expectancy')
    
decorate(xlabel='Year', 
             ylabel='Life Expectancy',
             title='life_expectancy')

# %%
un = tables.UN / 1e9
empty = TimeSeries()
plot_results(un, empty, 'UN DESA')
    
decorate(xlabel='Year', 
             ylabel='World population (billion)',
             title='Estimated world population')

# %%
young = get_first_value(un) * 0.378
old= get_first_value(un) * 0.2
middle = get_first_value(un)*0.422
init = State(young=young, middle=middle, old=old)
# Out:
# young     1.258408
# middle    1.404890
# old       0.665824
# dtype: float64

# %%
#death_rate = 1/((life_expectancy)-old_age)
birth_rate = fer_rate/(31*2);

#children per woman in her fer age per year

# %%
system = System(mature_rate = 1/19,
                elder_rate = 1/(44-20),
                t_0 = 1965,
                t_end = 2016,
                init=init)
# Out:
# mature_rate                                            0.0526316
# elder_rate                                             0.0416667
# t_0                                                         1965
# t_end                                                       2016
# init           young     1.258408
# middle    1.404890
# old     ...
# dtype: object

# %%
def update_func1(state, t, system):
    
    if(t>=1965 and t < 1992):
        old_age=44
    if (t>=1992):
        old_age=54
    death_rate = 1/((life_expectancy)-old_age)
    birth_rate2 = birth_rate[t]
    births = birth_rate2*state.middle
    system.elder_rate = 1/(old_age-19)
    maturings = system.mature_rate * state.young
    agings = system.elder_rate * state.middle
    death_rate = 1/(life_expectancy-old_age)
    
    deaths = death_rate * state.old
    young = state.young + births - maturings
    middle = state.middle + maturings - agings
    old = state.old + agings - deaths
    #print(death_rate,deaths)
    
    return State(young=young, middle=middle, old=old)

# %%
state = update_func1(init, system.t_0, system)
# Out:
# young                                               1.30604
# middle                                              1.41493
# old       1965    0.650125
# 1966    0.656097
# 1967    0.66...
# dtype: object

# %%
state = update_func1(state, system.t_0, system)
# Out:
# young                                               1.35198
# middle                                              1.42707
# old       1965    0.636521
# 1966    0.647734
# 1967    0.65...
# dtype: object

# %%
def run_simulation(system, update_func):
    """Simulate the system using any update function.
    
    init: initial State object
    system: System object
    update_func: function that computes the population next year
    
    returns: TimeSeries
    """
    results = TimeSeries()
    
    state = system.init
    results[system.t_0] = state.young + state.middle + state.old
    
    for t in linrange(system.t_0, system.t_end):
        state = update_func(state, t, system)
        results[t+1] = state.young + state.middle + state.old
        
    return results

# %%
results = run_simulation(system, update_func1);
plot_results(un, results, 'World population estimates')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-86428e198f8c> in <module>()
#       1 results = run_simulation(system, update_func1);
# ----> 2 plot_results(un, results, 'World population estimates')
#
# <ipython-input-84-4c832b53c038> in plot_results(life_expectancy, timeseries, title)
#       8     """
#       9     plot(life_expectancy, '--', label='UN DESA')
# ---> 10     plot(timeseries, color='gray', label='model')
#      11
#      12     decorate(xlabel='Year',
#
# ~\ModSimPy\code\modsim.py in plot(*args, **options)
#     671         lines = plt.plot(x, y, style, **options)
#     672     else:
# --> 673         lines = plt.plot(x, y, **options)
#     674     return lines
#     675
#
# C:\Miniconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# C:\Miniconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\Miniconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1526         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1527
# -> 1528         for line in self._get_lines(*args, **kwargs):
#    1529             self.add_line(line)
#    1530             lines.append(line)
#
# C:\Miniconda3\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# C:\Miniconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     377         if len(tup) == 2:
#     378             x = _check_1d(tup[0])
# --> 379             y = _check_1d(tup[-1])
#     380         else:
#     381             x, y = index_of(tup[-1])
#
# C:\Miniconda3\lib\site-packages\matplotlib\cbook\__init__.py in _check_1d(x)
#    2059     '''
#    2060     if not hasattr(x, 'shape') or len(x.shape) < 1:
# -> 2061         return np.atleast_1d(x)
#    2062     else:
#    2063         try:
#
# C:\Miniconda3\lib\site-packages\numpy\core\shape_base.py in atleast_1d(*arys)
#      50     res = []
#      51     for ary in arys:
# ---> 52         ary = asanyarray(ary)
#      53         if ary.ndim == 0:
#      54             result = ary.reshape(1)
#
# C:\Miniconda3\lib\site-packages\numpy\core\numeric.py in asanyarray(a, dtype, order)
#     551
#     552     """
# --> 553     return array(a, dtype, copy=False, order=order, subok=True)
#     554
#     555
#
# ValueError: setting an array element with a sequence.

# %% [markdown]
# Interpretation:
